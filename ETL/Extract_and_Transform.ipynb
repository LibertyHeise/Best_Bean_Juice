# %% [markdown]
# ## Extract

# %%
# Import our dependencies
#from sklearn.model_selection import train_test_split
#from sklearn.preprocessing import StandardScaler
import pandas as pd
from datetime import datetime
import string
from sqlalchemy import create_engine
#import tensorflow as tf

#  Import and read the charity_data.csv.
from google.colab import drive
drive.mount('/content/drive')
origin_df = pd.read_csv("/content/drive/Drive/Project4_CoffeeQuality/coffee_ratings.csv")
origin_df.head()
# Out:
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-d18f562aed14> in <module>
#      11 from google.colab import drive
#      12 drive.mount('/content/drive')
# ---> 13 origin_df = pd.read_csv("/content/drive/Drive/Project4_CoffeeQuality/coffee_ratings.csv")
#      14 origin_df.head()
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/Drive/Project4_CoffeeQuality/coffee_ratings.csv'

# %% [markdown]
# ## Transform

# %%
#choose the most important flavor criteria and make a dataframe
flavor_profile_df = origin_df[["total_cup_points", "aroma","flavor", "aftertaste", "acidity", "body", "balance", "sweetness", "moisture"]]
flavor_profile_df
# Out:
#       total_cup_points  aroma  flavor  aftertaste  acidity  body  balance  \
# 0                90.58   8.67    8.83        8.67     8.75  8.50     8.42
# 1                89.92   8.75    8.67        8.50     8.58  8.42     8.42
# 2                89.75   8.42    8.50        8.42     8.42  8.33     8.42
# 3                89.00   8.17    8.58        8.42     8.42  8.50     8.25
# 4                88.83   8.25    8.50        8.25     8.50  8.42     8.33
# ...                ...    ...     ...         ...      ...   ...      ...
# 1334             78.75   7.75    7.58        7.33     7.58  5.08     7.83
# 1335             78.08   7.50    7.67        7.75     7.75  5.17     5.25
# 1336             77.17   7.33    7.33        7.17     7.42  7.50     7.17
# 1337             75.08   7.42    6.83        6.75     7.17  7.25     7.00
# 1338             73.75   6.75    6.67        6.50     6.83  6.92     6.83
#
#       sweetness  moisture
# 0         10.00      0.12
# 1         10.00      0.12
# 2         10.00      0.00
# 3         10.00      0.11
# 4         10.00      0.12
# ...         ...       ...
# 1334       7.75      0.00
# 1335       8.42      0.00
# 1336       7.42      0.00
# 1337       7.08      0.10
# 1338       6.67      0.12
#
# [1339 rows x 9 columns]

# %%
#drop nulls
flavor_profile_df = flavor_profile_df.dropna()
flavor_profile_df
# Out:
#       total_cup_points  aroma  flavor  aftertaste  acidity  body  balance  \
# 0                90.58   8.67    8.83        8.67     8.75  8.50     8.42
# 1                89.92   8.75    8.67        8.50     8.58  8.42     8.42
# 2                89.75   8.42    8.50        8.42     8.42  8.33     8.42
# 3                89.00   8.17    8.58        8.42     8.42  8.50     8.25
# 4                88.83   8.25    8.50        8.25     8.50  8.42     8.33
# ...                ...    ...     ...         ...      ...   ...      ...
# 1334             78.75   7.75    7.58        7.33     7.58  5.08     7.83
# 1335             78.08   7.50    7.67        7.75     7.75  5.17     5.25
# 1336             77.17   7.33    7.33        7.17     7.42  7.50     7.17
# 1337             75.08   7.42    6.83        6.75     7.17  7.25     7.00
# 1338             73.75   6.75    6.67        6.50     6.83  6.92     6.83
#
#       sweetness  moisture
# 0         10.00      0.12
# 1         10.00      0.12
# 2         10.00      0.00
# 3         10.00      0.11
# 4         10.00      0.12
# ...         ...       ...
# 1334       7.75      0.00
# 1335       8.42      0.00
# 1336       7.42      0.00
# 1337       7.08      0.10
# 1338       6.67      0.12
#
# [1339 rows x 9 columns]

# %%
#choose the most important demographic & processing criteria and make a dataframe
demographic_df = origin_df[["country_of_origin", "owner", "harvest_year", "grading_date", "altitude","processing_method"]]
demographic_df
# Out:
#      country_of_origin                     owner harvest_year  \
# 0             Ethiopia                 metad plc         2014
# 1             Ethiopia                 metad plc         2014
# 2            Guatemala  grounds for health admin          NaN
# 3             Ethiopia       yidnekachew dabessa         2014
# 4             Ethiopia                 metad plc         2014
# ...                ...                       ...          ...
# 1334           Ecuador               luis robles         2016
# 1335           Ecuador               luis robles         2016
# 1336     United States               james moore         2014
# 1337             India             cafe politico         2013
# 1338           Vietnam             cafe politico         2013
#
#              grading_date       altitude processing_method
# 0         April 4th, 2015      1950-2200      Washed / Wet
# 1         April 4th, 2015      1950-2200      Washed / Wet
# 2          May 31st, 2010  1600 - 1800 m               NaN
# 3        March 26th, 2015      1800-2200     Natural / Dry
# 4         April 4th, 2015      1950-2200      Washed / Wet
# ...                   ...            ...               ...
# 1334   January 19th, 2016            NaN               NaN
# 1335   January 19th, 2016             40               NaN
# 1336  December 23rd, 2014     795 meters     Natural / Dry
# 1337    August 25th, 2014            NaN     Natural / Dry
# 1338    August 25th, 2014            NaN     Natural / Dry
#
# [1339 rows x 6 columns]

# %%
#drop nulls
demographic_df = demographic_df.dropna()
demographic_df
# Out:
#      country_of_origin                   owner harvest_year  \
# 0             Ethiopia               metad plc         2014
# 1             Ethiopia               metad plc         2014
# 3             Ethiopia     yidnekachew dabessa         2014
# 4             Ethiopia               metad plc         2014
# 9             Ethiopia  diamond enterprise plc         2014
# ...                ...                     ...          ...
# 1322             India          nishant gurjer         2015
# 1327             India           andrew hetzel         2013
# 1332             India           andrew hetzel         2013
# 1333     United States           andrew hetzel         2012
# 1336     United States             james moore         2014
#
#              grading_date    altitude processing_method
# 0         April 4th, 2015   1950-2200      Washed / Wet
# 1         April 4th, 2015   1950-2200      Washed / Wet
# 3        March 26th, 2015   1800-2200     Natural / Dry
# 4         April 4th, 2015   1950-2200      Washed / Wet
# 9        March 30th, 2015   1795-1850     Natural / Dry
# ...                   ...         ...               ...
# 1322    August 23rd, 2016        1000     Natural / Dry
# 1327       June 3rd, 2013        750m     Natural / Dry
# 1332      June 20th, 2013        750m     Natural / Dry
# 1333  February 29th, 2012       3000'     Natural / Dry
# 1336  December 23rd, 2014  795 meters     Natural / Dry
#
# [1002 rows x 6 columns]

# %%
# convert the 'Date' column to datetime format
demographic_df['grading_date']= pd.to_datetime(demographic_df['grading_date'])
# Check the format of 'Date' column
demographic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1002 entries, 0 to 1336
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country_of_origin  1002 non-null   object
#  1   owner              1002 non-null   object
#  2   harvest_year       1002 non-null   object
#  3   grading_date       1002 non-null   datetime64[ns]
#  4   altitude           1002 non-null   object
#  5   processing_method  1002 non-null   object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 54.8+ KB
# <ipython-input-16-a3923d92e7e7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   demographic_df['grading_date']= pd.to_datetime(demographic_df['grading_date'])

# %%
demographic_df['grading_year'] = pd.DatetimeIndex(demographic_df['grading_date']).year
demographic_df
# Out:
# <ipython-input-17-2c0ddf0f86fd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   demographic_df['grading_year'] = pd.DatetimeIndex(demographic_df['grading_date']).year
#      country_of_origin                   owner harvest_year grading_date  \
# 0             Ethiopia               metad plc         2014   2015-04-04
# 1             Ethiopia               metad plc         2014   2015-04-04
# 3             Ethiopia     yidnekachew dabessa         2014   2015-03-26
# 4             Ethiopia               metad plc         2014   2015-04-04
# 9             Ethiopia  diamond enterprise plc         2014   2015-03-30
# ...                ...                     ...          ...          ...
# 1322             India          nishant gurjer         2015   2016-08-23
# 1327             India           andrew hetzel         2013   2013-06-03
# 1332             India           andrew hetzel         2013   2013-06-20
# 1333     United States           andrew hetzel         2012   2012-02-29
# 1336     United States             james moore         2014   2014-12-23
#
#         altitude processing_method  grading_year
# 0      1950-2200      Washed / Wet          2015
# 1      1950-2200      Washed / Wet          2015
# 3      1800-2200     Natural / Dry          2015
# 4      1950-2200      Washed / Wet          2015
# 9      1795-1850     Natural / Dry          2015
# ...          ...               ...           ...
# 1322        1000     Natural / Dry          2016
# 1327        750m     Natural / Dry          2013
# 1332        750m     Natural / Dry          2013
# 1333       3000'     Natural / Dry          2012
# 1336  795 meters     Natural / Dry          2014
#
# [1002 rows x 7 columns]

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# path = '/content/drive/My Drive/Project4_CoffeeQuality/Resources/ETL.csv'
# with open(path, 'w', encoding = 'utf-8-sig') as f:
#   demographic_df.to_csv(f)

# %%
#  Import and read the charity_data.csv.
from google.colab import drive
drive.mount('/content/drive')
cleaned_df = pd.read_csv("/content/drive/MyDrive/Project4_CoffeeQuality/Resources/New_ETL.csv")
cleaned_df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Unnamed: 0 country_of_origin                   owner  harvest_year  \
# 0           0          Ethiopia               metad plc          2014
# 1           1          Ethiopia               metad plc          2014
# 2           3          Ethiopia     yidnekachew dabessa          2014
# 3           4          Ethiopia               metad plc          2014
# 4           9          Ethiopia  diamond enterprise plc          2014
#
#   grading_date  altitude processing_method  grading_year
# 0   2015-04-04      1985      Washed / Wet          2015
# 1   2015-04-04      1985      Washed / Wet          2015
# 2   2015-03-26      1985     Natural / Dry          2015
# 3   2015-04-04      1985      Washed / Wet          2015
# 4   2015-03-30      1800     Natural / Dry          2015

# %%
cleaned_df["year_diff"] = cleaned_df["grading_year"]- cleaned_df["harvest_year"]
cleaned_df
# Out:
#       Unnamed: 0 country_of_origin                   owner  harvest_year  \
# 0              0          Ethiopia               metad plc          2014
# 1              1          Ethiopia               metad plc          2014
# 2              3          Ethiopia     yidnekachew dabessa          2014
# 3              4          Ethiopia               metad plc          2014
# 4              9          Ethiopia  diamond enterprise plc          2014
# ...          ...               ...                     ...           ...
# 997         1322             India          nishant gurjer          2015
# 998         1327             India           andrew hetzel          2013
# 999         1332             India           andrew hetzel          2013
# 1000        1333     United States           andrew hetzel          2012
# 1001        1336     United States             james moore          2014
#
#      grading_date  altitude processing_method  grading_year  year_diff
# 0      2015-04-04      1985      Washed / Wet          2015          1
# 1      2015-04-04      1985      Washed / Wet          2015          1
# 2      2015-03-26      1985     Natural / Dry          2015          1
# 3      2015-04-04      1985      Washed / Wet          2015          1
# 4      2015-03-30      1800     Natural / Dry          2015          1
# ...           ...       ...               ...           ...        ...
# 997    2016-08-23      1000     Natural / Dry          2016          1
# 998    2013-06-03       750     Natural / Dry          2013          0
# 999    2013-06-20       750     Natural / Dry          2013          0
# 1000   2012-02-29       914     Natural / Dry          2012          0
# 1001   2014-12-23       795     Natural / Dry          2014          0
#
# [1002 rows x 9 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/Project4_CoffeeQuality/Resources/demographic.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  cleaned_df.to_csv(f)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/My Drive/Project4_CoffeeQuality/Resources/flavor.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  flavor_profile_df.to_csv(f)
