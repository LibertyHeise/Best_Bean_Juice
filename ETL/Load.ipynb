# %%
import pandas as pd
from sqlalchemy import create_engine

demographic_df = pd.read_csv("../Resources/demographic.csv")
flavor_df = pd.read_csv("../Resources/flavor.csv")

# %%
coffee_df = pd.concat([demographic_df, flavor_df], axis=1, join='inner')
coffee_df
# Out:
#       Unnamed: 0.1  Unnamed: 0 country_of_origin                   owner  \
# 0                0           0          Ethiopia               metad plc
# 1                1           1          Ethiopia               metad plc
# 2                2           3          Ethiopia     yidnekachew dabessa
# 3                3           4          Ethiopia               metad plc
# 4                4           9          Ethiopia  diamond enterprise plc
# ...            ...         ...               ...                     ...
# 997            997        1322             India          nishant gurjer
# 998            998        1327             India           andrew hetzel
# 999            999        1332             India           andrew hetzel
# 1000          1000        1333     United States           andrew hetzel
# 1001          1001        1336     United States             james moore
#
#       harvest_year grading_date  altitude processing_method  grading_year  \
# ...

# %%
protocol = 'postgresql'
username = 'postgres'
password = 'postgres'
host = 'localhost'
port = 5432
database_name = 'bean_juice_db'

rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)

# %%
demographic_df.to_sql(name='demographic', con=engine, if_exists='append', index=False)
flavor_df.to_sql(name='flavor', con=engine, if_exists='append', index=False)
coffee_df.to_sql(name='coffee', con=engine, if_exists='append', index=False)
# Out:
# 2
