# %%
import pandas as pd
from sqlalchemy import create_engine
from google.colab import drive

drive.mount('/content/gdrive')

demographic_df = pd.read_csv("/content/gdrive/MyDrive/Project4_CoffeeQuality/Resources/demographic.csv")
flavor_df = pd.read_csv("/content/gdrive/MyDrive/Project4_CoffeeQuality/Resources/flavor.csv")
# Out:
# Mounted at /content/gdrive

# %%
coffee_df = pd.concat([demographic_df, flavor_df], axis=1, join='inner')
coffee_df
# Out:
#       Unnamed: 0.1  Unnamed: 0 country_of_origin                   owner  \
# 0                0           0          Ethiopia               metad plc
# 1                1           1          Ethiopia               metad plc
# 2                2           3          Ethiopia     yidnekachew dabessa
# 3                3           4          Ethiopia               metad plc
# 4                4           9          Ethiopia  diamond enterprise plc
# ...            ...         ...               ...                     ...
# 997            997        1322             India          nishant gurjer
# 998            998        1327             India           andrew hetzel
# 999            999        1332             India           andrew hetzel
# 1000          1000        1333     United States           andrew hetzel
# 1001          1001        1336     United States             james moore
#
#       harvest_year grading_date  altitude processing_method  grading_year  \
# ...

# %%
# import pyodbc 
# conn = pyodbc.connect('Driver={SQL Server};'
#                       'Server=DESKTOP-CRBEE2U\bean_juice_db;'
#                       'Database=bean_juice_db;'
#                       'Trusted_Connection=yes;')

# cursor = conn.cursor()

# %%
# !pip install mysql-connector-python
# import mysql.connector
# !pip install psycopg2
import psycopg2

protocol = 'postgresql'
username = 'postgres'
password = 'postgres'
host = 'localhost'
port = 5432
database_name = 'bean_juice_db'


# Establish the database connection
psconn = psycopg2.connect(user=username, port=port, password=password, host=host, database=database_name)

# rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
# engine = create_engine(rds_connection_string)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-19-0ca014fce7a4> in <module>
#      13
#      14 # Establish the database connection
# ---> 15 psconn = psycopg2.connect(user=username, port=port, password=password, host=host, database=database_name)
#      16
#      17 # rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
#
# /usr/local/lib/python3.9/dist-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# ...

# %%
demographic_df.to_sql(name='demographic', con=engine, if_exists='append', index=False)
flavor_df.to_sql(name='flavor', con=engine, if_exists='append', index=False)
coffee_df.to_sql(name='coffee', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3360         try:
# -> 3361             return fn()
#    3362         except dialect.dbapi.Error as e:
#
# /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py in connect(self)
#     326         """
# --> 327         return _ConnectionFairy._checkout(self)
#     328
#
# /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     893         if not fairy:
# --> 894             fairy = _ConnectionRecord.checkout(pool)
#     895
#
# /usr/local/lib/python3.9/dist-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     492     def checkout(cls, pool):
# --> 493         rec = pool._do_get()
#     494         try:
#
# ...
